# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

# %%
# ratings = pd.read_csv((os.path.join('..', 'Resources', 'us_bond_funds_063019.csv')))
ratings = pd.read_csv('Resources/us_bond_funds_063019.csv')
ratings.tail()
# Out:
#                              Group/Investment Ticker Inception Date  \
# 1580      Vanguard Total Intl Bd Idx Admiral™  VTABX        5/31/13
# 1581            Vanguard Total World Bond ETF   BNDW         9/5/18
# 1582     WisdomTree Yield Enh Glbl Aggt Bd Fd   GLBY       12/11/18
# 1583  Xtrackers Barclays Intl Corp Bd Hdg ETF   IFIX       10/25/16
# 1584   Xtrackers Barclays Intl Trs Bd Hdg ETF   IGVT       10/25/16
#
#                Morningstar Category Index Analysis Date Analyst Rating  \
# 1580  US Fund World Bond-USD Hedged   Yes       9/24/18         Silver
# 1581  US Fund World Bond-USD Hedged   Yes           NaN            NaN
# 1582  US Fund World Bond-USD Hedged   Yes           NaN            NaN
# 1583  US Fund World Bond-USD Hedged   Yes           NaN            NaN
# 1584  US Fund World Bond-USD Hedged   Yes           NaN            NaN
#
#      People Rating Process Rating Parent Rating     ...      2008 Return  \
# ...

# %%
#Filter by ranked funds only
#Drop unnamed columns and list all column headings
filtered_by_analyst_rating = ratings.dropna(subset=['Analyst Rating']).drop(['Unnamed: 148', 'Unnamed: 149', 'Unnamed: 150', 'Unnamed: 151','Unnamed: 152', 'Unnamed: 153'],axis=1)
list(filtered_by_analyst_rating)
# Out:
# ['Group/Investment',
#  'Ticker',
#  'Inception Date',
#  'Morningstar Category',
#  'Index',
#  'Analysis Date',
#  'Analyst Rating',
#  'People Rating',
#  'Process Rating',
#  'Parent Rating',
#  'Performance Rating',
#  'Price Rating',
#  'Star Rating',
#  'Prospectus Adjusted Operating Expense Ratio',
#  'Morningstar Fee Level Rank - Distribution',
#  'Fund Size',
#  'Fund Size Rank',
#  'Est Fund-Level Net Flow 1 Yr',
#  'Est Fund-Level Net Flow 1 Yr Rank',
#  'Est Fund-Level Net Flow 3 Yr',
#  'Est Fund-Level Net Flow 3 Yr Rank',
#  'Est Fund-Level Net Flow 5 Yr',
#  'Est Fund-Level Net Flow 5 Yr Rank',
#  'Flows % 1 Yr',
#  'Flows % 1 Yr Rank',
#  'Manager Tenure - Longest',
#  'Manager Tenure - Longest Rank',
#  'Manager Tenure - Average',
#  'Manager Tenure - Average Rank',
#  'Manager Ownership Level',
#  '12 Mo Yield',
#  '12 Mo Yield Rank',
#  'Eff Duration',
#  'Eff Duration Rank',
#  'Credit Qual AAA %',
#  'Credit Qual AAA Rank',
#  'Credit Qual AA %',
# ...

# %%
X = filtered_by_analyst_rating[['Fund Size Rank', 'Flows % 1 Yr Rank', '12 Mo Yield Rank', 'Eff Duration Rank', 'Credit Qual AAA Rank']]
y = filtered_by_analyst_rating['Analyst Rating'].values.reshape(-1, 1)
# print(X.shape, y.shape)

#Replace NaN in rankings with 50.
X.fillna(value=50.0)
X_without_na = X.fillna(value=50.0)
# Out:
#       Fund Size Rank  Flows % 1 Yr Rank  12 Mo Yield Rank  Eff Duration Rank  \
# 8               41.0               30.0              57.0               84.0
# 9               19.0               70.0              54.0                9.0
# 10              78.0               73.0              15.0               69.0
# 14              33.0               56.0              68.0                1.0
# 15               5.0               35.0              30.0               82.0
# 17               7.0               43.0              78.0               75.0
# 19               4.0               37.0              52.0               50.0
# 22              30.0               15.0              89.0               23.0
# 29              14.0               57.0               7.0               58.0
# 31              21.0               34.0              59.0               50.0
# 32               1.0               52.0              23.0               47.0
# ...

# %%
# Split the data into training and testing

### BEGIN SOLUTION
from sklearn.model_selection import train_test_split

X_without_na_train, X_without_na_test, y_train, y_test = train_test_split(X, y, random_state=42)
### END SOLUTION

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScater model and fit it to the training data

### BEGIN SOLUTION
X_without_na_scaler = StandardScaler().fit(X_without_na_train)
y_scaler = StandardScaler().fit(y_train)
### END SOLUTION
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-33d45e63df21> in <module>
#       5 ### BEGIN SOLUTION
#       6 X_without_na_scaler = StandardScaler().fit(X_without_na_train)
# ----> 7 y_scaler = StandardScaler().fit(y_train)
#       8 ### END SOLUTION
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/preprocessing/data.py in fit(self, X, y)
#     623         # Reset internal state before fitting
#     624         self._reset()
# --> 625         return self.partial_fit(X, y)
#     626
#     627     def partial_fit(self, X, y=None):
#
# ~/anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/preprocessing/data.py in partial_fit(self, X, y)
#     647         X = check_array(X, accept_sparse=('csr', 'csc'), copy=self.copy,
#     648                         warn_on_dtype=True, estimator=self, dtype=FLOAT_DTYPES,
# ...
